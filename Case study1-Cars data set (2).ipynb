# %% [markdown]
# # Cars Data set

# %%
#Data set

# %%
#Initial setup
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Question1-reading Dataset to python environment.
import pandas as pd
data=pd.read_csv("cars_data.csv")

# %%
data=pd.DataFrame(data)
data
# Out:
#          Make        Model    Nickname Car Gender Buyer Gender  Buyer Age  \
# 0      Suzuki       Vitara  Philippine     Female       Female         51
# 1       Honda        S2000      Henrik       Male         Male         30
# 2         BMW           Z4      Lebbie       Male       Female         54
# 3      Toyota       Tacoma    Jefferey     Female         Male         68
# 4        Ford      Festiva     Glendon     Female         Male         70
# ...       ...          ...         ...        ...          ...        ...
# 9995    Mazda      Tribute      Cooper       Male         Male         44
# 9996      GMC  Sierra 2500         Dud       Male         Male         40
# 9997  Mercury      Mariner     Chariot       Male         Male         37
# 9998   Daewoo      Leganza       Dynah     Female       Female         21
# 9999   Toyota      Sequoia    Zedekiah     Female         Male         21
#
#            Buzzword      Country             City  Dealer Latitude  \
# ...

# %%
#Question2-Checking the null values present in the data set.
data=pd.DataFrame(data)
haveNull=data.isnull().values.any()
if(haveNull):
    print("There are null values")
else:
    print("There are no null values")
# Out:
# There are no null values

# %%
#Question3-find the top five cars based on their sales price.
data=pd.read_csv("cars_data.csv")
data.shape
# Out:
# (10000, 20)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               10000 non-null  object
#  1   Model              10000 non-null  object
#  2   Nickname           10000 non-null  object
#  3   Car Gender         10000 non-null  object
#  4   Buyer Gender       10000 non-null  object
#  5   Buyer Age          10000 non-null  int64
#  6   Buzzword           10000 non-null  object
#  7   Country            10000 non-null  object
#  8   City               10000 non-null  object
#  9   Dealer Latitude    10000 non-null  float64
#  10  Dealer Longitude   10000 non-null  float64
#  11  Color              10000 non-null  object
#  12  New Car            10000 non-null  bool
#  13  Purchase Date      10000 non-null  object
#  14  Sale Price         10000 non-null  float64
#  15  Discount           10000 non-null  float64
# ...

# %%
data[['Make','Model','Nickname','Sale Price']].sort_values(by=['Sale Price'],ascending=False).head(5)
# Out:
#             Make      Model   Nickname  Sale Price
# 5984  Volkswagen  Jetta III    Rachael    99997.65
# 1270        Audi         A6      Thorn    99991.91
# 3460       Lexus         LX      Aldin    99983.38
# 9032       Mazda       MX-6  Sylvester    99978.17
# 302        Lexus         ES       Brig    99973.44

# %%
#Cars with lowest Resell price
data[['Make', 'Model', 'Nickname', 'New Car', 'Sale Price', 'Resell Price']].sort_values(by=['Resell Price'], ascending=True).head(5)
# Out:
#             Make        Model Nickname  New Car  Sale Price  Resell Price
# 2446   Chevrolet         1500  Corenda    False    49909.44       2000.84
# 4933         GMC  Savana 1500     Lark    False    80084.82       2005.44
# 566       Jaguar           XF   Payton     True    24124.99       2014.09
# 2538  Mitsubishi       3000GT     Thia     True    88195.95       2017.24
# 5869    Infiniti          G37    Sonny    False    77791.65       2017.83

# %%
#Bar graphs of male vs female
plt.figure(figsize=(6, 5))
ax = sns.countplot(x = 'Buyer Gender', data = pd.DataFrame)
for bar in ax.patches:
    y_value = bar.get_height()
    x_value = bar.get_x() + 0.4
    ax.annotate(f'\n{y_value}', (x_value, y_value), ha='center', va='top', color='white', size=14)
plt.title("Female vs Male participants in the sale", size=14)
plt.xlabel('Buyer Gender', size = 13)
plt.ylabel('Count', size = 13)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-d8cd0aeef770> in <module>
#       1 #Bar graphs of male vs female
#       2 plt.figure(figsize=(6, 5))
# ----> 3 ax = sns.countplot(x = 'Buyer Gender', data = pd.DataFrame)
#       4 for bar in ax.patches:
#       5     y_value = bar.get_height()
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3593         raise ValueError("Cannot pass values for both `x` and `y`")
#    3594
# ...
